# %%
import os

print("/kaggle/input contents:")
print(os.listdir("/kaggle/input"))
# Out:
# /kaggle/input contents:
# ['datasets']

# %%
print(os.listdir("/kaggle/input/datasets/karinalam2/brailledetect"))
# Out:
# ['README.dataset.txt', 'README.roboflow.txt', 'data.yaml', 'valid', 'test', 'train']

# %%
# !pip install -q ultralytics

# %%
from ultralytics import YOLO
import torch
import os

# %%
print(torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
DATASET_PATH = "/kaggle/input/datasets/karinalam2/brailledetect"

print(os.listdir(DATASET_PATH))
# Out:
# ['README.dataset.txt', 'README.roboflow.txt', 'data.yaml', 'valid', 'test', 'train']

# %%
import os

for root, dirs, files in os.walk("/kaggle/input"):
    for file in files:
        if file == "data.yaml":
            print(os.path.join(root, file))
# Out:
# /kaggle/input/datasets/karinalam2/brailledetect/data.yaml

# %%
model = YOLO("yolov8n.pt")

# %%
import os

for root, dirs, files in os.walk("/kaggle/working"):
    for file in files:
        if file == "best.pt":
            print(os.path.join(root, file))

# %%
import os

for root, dirs, files in os.walk("/kaggle/working"):
    for file in files:
        if file == "best.pt":
            print(os.path.join(root, file))

# %%
results = model.train(
    data="/kaggle/input/datasets/karinalam2/brailledetect/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,
    workers=2,
    pretrained=True,
    cache=True,
    save=True,
    plots=True,
    project="/kaggle/working",
    name="BrailleYOLOv8"
)
# Out:
# Ultralytics 8.4.102 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# ...

# %%
# !pip install -q ultralytics

# %%
from ultralytics import YOLO

import os
import cv2
import shutil
import numpy as np

from tqdm import tqdm

# %%
MODEL_PATH = "/kaggle/working/BrailleYOLOv8/weights/best.pt"

model = YOLO(MODEL_PATH)

# %%
import os

print(os.path.exists("/kaggle/working/BrailleYOLOv11"))
# Out:
# True
